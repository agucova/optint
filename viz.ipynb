# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

from model import optimize_beds

sns.set_theme(palette="rocket")

# %%
general_metrics, metrics_by_block = optimize_beds(120, 105, [10, 500, 200])
# Out:
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-07-12
# Using license file /home/agucova/.gurobi/gurobi.lic
# Using gurobi.env file
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 262485 rows, 166320 columns and 1428483 nonzeros
# Model fingerprint: 0xe9306215
# Variable types: 0 continuous, 166320 integer (166320 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [5e+01, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Presolve removed 178422 rows and 117792 columns
# Presolve time: 1.41s
# Presolved: 84063 rows, 48528 columns, 353749 nonzeros
# Variable types: 0 continuous, 48528 integer (48528 binary)
# Found heuristic solution: objective 310600.00000
#
# ...

# %%
metrics_by_block
# Out:
#     time  changes_per_block  not_ideals_per_block  patients_per_block  \
# 0      0                  0                     9                  80
# 1      2                  0                     9                  80
# 2      4                  0                    10                  81
# 3      6                  0                    10                  83
# 4      8                  0                    10                  83
# 5     10                  0                     9                  79
# 6     12                  0                     9                  73
# 7     14                  0                     9                  75
# 8     16                  0                     9                  75
# 9     18                  0                     9                  77
# 10    20                  1                     9                  73
# 11    22                  0                     7                  73
#
#     dist_per_block
# 0              780
# ...

# %%
fig, axes = plt.subplots(2, 2, sharex=True, figsize=(12,12))
fig.suptitle('Métricas durante el día')
axes[0,0].set_title("Cambios por bloque")
sns.lineplot(x="time", y="changes_per_block", data=metrics_by_block, ax=axes[0, 0], linewidth=3)
axes[1,1].set_title("Distancia por bloque")
sns.lineplot(x="time", y="dist_per_block", data=metrics_by_block, ax=axes[1, 1], linewidth=3)
axes[0,1].set_title("Pacientes no ideales por bloque")
sns.lineplot(x="time", y="not_ideals_per_block", data=metrics_by_block, ax=axes[0, 1], linewidth=3)
axes[1,0].set_title("Pacientes por bloque")
sns.lineplot(x="time", y="patients_per_block", data=metrics_by_block, ax=axes[1, 0], linewidth=3)
# Out:
# <AxesSubplot:title={'center':'Pacientes por bloque'}, xlabel='time', ylabel='patients_per_block'>
