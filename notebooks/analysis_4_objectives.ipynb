# %% [markdown]
# # Analisis de sensibilidad

# %%
# %cd ..
import pandas as pd
from tqdm import tqdm
import seaborn as sns
from matplotlib import pyplot as plt

from model import optimize_beds

sns.set_theme(palette="rocket")
# Out:
# c:\Users\iamsm\Documents\Acceso UC\Opti\Proyecto\optint

# %% [markdown]
# ### Funciones de graficos

# %%
def graph_by_metrics(graph_metrics):
    # graph_metrics = pd.read_csv(f"analysis_per_blocks/metrics_by_block_{w1}_{w2}_{w3}.csv")
    fig, axes = plt.subplots(2, 2, sharex=True, figsize=(9, 9))
    fig.suptitle('Métricas durante el día')
    axes[0,0].set_title("Cambios por bloque")
    sns.lineplot(x="time", y="changes_per_block", data=graph_metrics, ax=axes[0, 0], linewidth=3)
    axes[1,1].set_title("Distancia por bloque")
    sns.lineplot(x="time", y="dist_per_block", data=graph_metrics, ax=axes[1, 1], linewidth=3)
    axes[0,1].set_title("Pacientes no ideales por bloque")
    sns.lineplot(x="time", y="not_ideals_per_block", data=graph_metrics, ax=axes[0, 1], linewidth=3)
    axes[1,0].set_title("Pacientes por bloque")
    sns.lineplot(x="time", y="patients_per_block", data=graph_metrics, ax=axes[1, 0], linewidth=3)

# %%
def graph_by_weights(w1, w2, w3, w4):
    graph_metrics = pd.read_csv(f"analysis_4_blocks/metrics_by_block_{w1}_{w2}_{w3}_{w4}.csv")
    fig, axes = plt.subplots(2, 2, sharex=True, figsize=(12, 12))
    axes[0,0].set_title("Cambios por bloque")
    sns.lineplot(x="time", y="changes_per_block", data=graph_metrics, ax=axes[0, 0], linewidth=3)
    axes[1,1].set_title("Distancia por bloque")
    sns.lineplot(x="time", y="dist_per_block", data=graph_metrics, ax=axes[1, 1], linewidth=3)
    axes[0,1].set_title("Pacientes no ideales por bloque")
    sns.lineplot(x="time", y="not_ideals_per_block", data=graph_metrics, ax=axes[0, 1], linewidth=3)
    axes[1,0].set_title("Pacientes por bloque")
    sns.lineplot(x="time", y="patients_per_block", data=graph_metrics, ax=axes[1, 0], linewidth=3)

# %%
general_metrics, metrics_by_block = optimize_beds(130, 100, [1, 0, 0, 0])
print(general_metrics)
graph_by_metrics(metrics_by_block)

general_metrics, metrics_by_block = optimize_beds(130, 100, [-1, 0, 0, 0])
print(general_metrics)
graph_by_metrics(metrics_by_block)

# %%
general_metrics, metrics_by_block = optimize_beds(130, 100, [0, 1, 0, 0])
print(general_metrics)
graph_by_metrics(metrics_by_block)

general_metrics, metrics_by_block = optimize_beds(130, 100, [0, -1, 0, 0])
print(general_metrics)
graph_by_metrics(metrics_by_block)

# %%
general_metrics, metrics_by_block = optimize_beds(130, 100, [0, 0, 1, 0])
print(general_metrics)
graph_by_metrics(metrics_by_block)

general_metrics, metrics_by_block = optimize_beds(130, 100, [0, 0, -1, 0])
print(general_metrics)
graph_by_metrics(metrics_by_block)

# %%
general_metrics, metrics_by_block = optimize_beds(130, 100, [0, 0, 0, 1])
print(general_metrics)
graph_by_metrics(metrics_by_block)

general_metrics, metrics_by_block = optimize_beds(130, 100, [0, 0, 0, -1])
print(general_metrics)
graph_by_metrics(metrics_by_block)

# %% [markdown]
# Partiremos iterando sobre algunos casos y versu comportamiento, a partir de esto definiremos el rango

# %%
# Caso bonito
general_metrics, metrics_by_block = optimize_beds(130, 100, [1, 5, 20, 35])
print(general_metrics)
graph_by_metrics(metrics_by_block)
# Out:
# {'total_distance': 9935, 'beds_changed': 12, 'not_ideal': 108, 'status': 2, 'objective_1': 9935.0, 'objective_2': 81.0, 'objective_3': 108.0, 'objective_4': 12.0}

# %%
# Caso 
general_metrics, metrics_by_block = optimize_beds(130, 100, [1, 5, 20, 35])
print(general_metrics)

# %%
w2 -> 1, 10, 2 # 5
w3 -> 15, 25, 5 # 4
w4 -> 30, 40, 2 # 5

# %%
general_metrics, metrics_by_block = optimize_beds(130, 100, [1, 1, 20, 35])
print(general_metrics)
graph_by_metrics(metrics_by_block)

general_metrics, metrics_by_block = optimize_beds(130, 100, [1, 10, 20, 35])
print(general_metrics)
graph_by_metrics(metrics_by_block)
# Out:
# {'total_distance': 9935, 'beds_changed': 2, 'not_ideal': 108, 'status': 2, 'objective_1': 9935.0, 'objective_2': 11.0, 'objective_3': 108.0, 'objective_4': 2.0}
# {'total_distance': 9935, 'beds_changed': 20, 'not_ideal': 108, 'status': 2, 'objective_1': 9935.0, 'objective_2': 131.0, 'objective_3': 108.0, 'objective_4': 20.0}

# %%
general_metrics, metrics_by_block = optimize_beds(130, 100, [1, 5, 15, 35])
print(general_metrics)
graph_by_metrics(metrics_by_block)

general_metrics, metrics_by_block = optimize_beds(130, 100, [1, 5, 25, 35])
print(general_metrics)
graph_by_metrics(metrics_by_block)
# Out:
# {'total_distance': 9335, 'beds_changed': 11, 'not_ideal': 145, 'status': 2, 'objective_1': 9335.0, 'objective_2': 66.0, 'objective_3': 145.0, 'objective_4': 11.0}
# {'total_distance': 9935, 'beds_changed': 9, 'not_ideal': 108, 'status': 2, 'objective_1': 9935.0, 'objective_2': 60.0, 'objective_3': 108.0, 'objective_4': 9.0}

# %%
general_metrics, metrics_by_block = optimize_beds(130, 100, [1, 5, 20, 30])
print(general_metrics)
graph_by_metrics(metrics_by_block)

general_metrics, metrics_by_block = optimize_beds(130, 100, [1, 5, 20, 40])
print(general_metrics)
graph_by_metrics(metrics_by_block)
# Out:
# {'total_distance': 9935, 'beds_changed': 19, 'not_ideal': 108, 'status': 2, 'objective_1': 9935.0, 'objective_2': 126.0, 'objective_3': 108.0, 'objective_4': 19.0}
# {'total_distance': 9935, 'beds_changed': 2, 'not_ideal': 108, 'status': 2, 'objective_1': 9935.0, 'objective_2': 11.0, 'objective_3': 108.0, 'objective_4': 2.0}

# %% [markdown]
# Optamos por usar el rango de abajo para correr el codigo
# # ADVERTENCIA, EJECUTAR ESTE CODIGO SE PUEDE DEMORAR DEMASIADO, EL PC ANDA UN POCO LENTO AL CORRERLO

# %%
# w2 -> 1, 12, 2 # 5
# w3 -> 10, 31, 5 # 4
# w4 -> 31, 42, 2 # 5
# 21 iteraciones, esperar para ver resultados
w1 = 1
all_metrics = []
for w2 in range(1, 12, 2):
    for w3 in range(10, 31, 5):
        for w4 in range(31, 42, 2):
            general_metrics, metrics_by_block = optimize_beds(130, 100, [w1, w2, w3, w4])
            total_distance = general_metrics["total_distance"]
            beds_changed = general_metrics["beds_changed"]
            not_ideal = general_metrics["not_ideal"]
            print(f"w1: {w1}, w2: {w2}, w3: {w3}, w4: {w4}, {total_distance = }, {beds_changed = }, {not_ideal = }")
            general_metrics.update({"w1": w1, "w2": w2, "w3": w3, "w4": w4})
            all_metrics.append(general_metrics)
            if metrics_by_block is not None:
                metrics_by_block.to_csv(f"analysis_4_blocks/metrics_by_block_{w1}_{w2}_{w3}_{w4}.csv")
            print()

metrics = pd.DataFrame(all_metrics)
metrics.to_csv("cost_4_analysis.csv")
# Out:
# w1: 1, w2: 1, w3: 10, w4: 31, total_distance = 8635, beds_changed = 2, not_ideal = 200
#
# w1: 1, w2: 1, w3: 10, w4: 33, total_distance = 8645, beds_changed = 1, not_ideal = 202
#
# w1: 1, w2: 1, w3: 10, w4: 35, total_distance = 8525, beds_changed = 1, not_ideal = 214
#
# w1: 1, w2: 1, w3: 10, w4: 37, total_distance = 8645, beds_changed = 1, not_ideal = 202
#
# w1: 1, w2: 1, w3: 10, w4: 39, total_distance = 8765, beds_changed = 1, not_ideal = 190
#
# w1: 1, w2: 1, w3: 10, w4: 41, total_distance = 8645, beds_changed = 1, not_ideal = 202
#
# w1: 1, w2: 1, w3: 15, w4: 31, total_distance = 9220, beds_changed = 2, not_ideal = 154
#
# w1: 1, w2: 1, w3: 15, w4: 33, total_distance = 9145, beds_changed = 2, not_ideal = 159
#
# w1: 1, w2: 1, w3: 15, w4: 35, total_distance = 9220, beds_changed = 2, not_ideal = 154
#
# w1: 1, w2: 1, w3: 15, w4: 37, total_distance = 9400, beds_changed = 2, not_ideal = 142
#
# w1: 1, w2: 1, w3: 15, w4: 39, total_distance = 8995, beds_changed = 2, not_ideal = 169
# ...

# %% [markdown]
# # De aca en adelante los codigos son ejecutables, ya que leen los `.csv` que se guardaron en el codigo de arriba

# %% [markdown]
# ### Obtenemos los datos

# %%
metricas_generales = pd.read_csv("cost_4_analysis.csv")
metricas_generales
# Out:
#      Unnamed: 0  total_distance  beds_changed  not_ideal  status  objective_1  \
# 0             0            8635             2        200       2       8635.0
# 1             1            8645             1        202       2       8645.0
# 2             2            8525             1        214       2       8525.0
# 3             3            8645             1        202       2       8645.0
# 4             4            8765             1        190       2       8765.0
# ..          ...             ...           ...        ...     ...          ...
# 175         175            9935            20        108       2       9935.0
# 176         176           10115            20        102       2      10115.0
# 177         177           10385            20         93       2      10385.0
# 178         178            9935            20        108       2       9935.0
# 179         179           10115            20        102       2      10115.0
#
# ...

# %% [markdown]
# ### Printeo de minimos y maximos

# %%
metricas_generales.min()
# Out:
# Unnamed: 0           0.0
# total_distance    8525.0
# beds_changed         1.0
# not_ideal           93.0
# status               2.0
# objective_1       8525.0
# objective_2          2.0
# objective_3         93.0
# objective_4          1.0
# w1                   1.0
# w2                   1.0
# w3                  10.0
# w4                  31.0
# dtype: float64

# %%
metricas_generales.max()
# Out:
# Unnamed: 0          179.0
# total_distance    10385.0
# beds_changed         20.0
# not_ideal           214.0
# status                2.0
# objective_1       10385.0
# objective_2         131.0
# objective_3         214.0
# objective_4          20.0
# w1                    1.0
# w2                   11.0
# w3                   30.0
# w4                   41.0
# dtype: float64

# %%
metricas_filtradas = metricas_generales[metricas_generales["objective_1"] < 10000]
metricas_filtradas = metricas_filtradas[metricas_filtradas["not_ideal"] < 150]
metricas_filtradas = metricas_filtradas[metricas_filtradas["beds_changed"] >= 4]
metricas_filtradas = metricas_filtradas[metricas_filtradas["beds_changed"] <= 16]
metricas_filtradas
# Out:
#     Unnamed: 0  total_distance  beds_changed  not_ideal  status  objective_1  \
# 67          67            9380            16        142       2       9380.0
# 68          68            9335            11        145       2       9335.0
# 72          72            9935            15        108       2       9935.0
# 73          73            9935            15        108       2       9935.0
# 74          74            9935            12        108       2       9935.0
# 78          78            9935            15        108       2       9935.0
# 79          79            9935            15        108       2       9935.0
# 80          80            9935             9        108       2       9935.0
# 86          86            9935            11        108       2       9935.0
#
#     objective_2  objective_3  objective_4  w1  w2  w3  w4
# 67        101.0        142.0         16.0   1   5  15  33
# 68         66.0        145.0         11.0   1   5  15  35
# ...

# %%
print(metricas_filtradas.loc[[67, 74, 80], :])
# Out:
#     Unnamed: 0  total_distance  beds_changed  not_ideal  status  objective_1  \
# 67          67            9380            16        142       2       9380.0
# 74          74            9935            12        108       2       9935.0
# 80          80            9935             9        108       2       9935.0
#
#     objective_2  objective_3  objective_4  w1  w2  w3  w4
# 67        101.0        142.0         16.0   1   5  15  33
# 74         81.0        108.0         12.0   1   5  20  35
# 80         60.0        108.0          9.0   1   5  25  35

# %% [markdown]
# ## Valores a usar
# Los sets de datos mas interesantes son:
#
# 1) 1, 5, 15, 33
# Este caso se eligio por su baja distancia total y su alta cantidad de pacientes no ideales y el mayor numero de cambios de camas
#
# 2) 1, 5, 20, 35
# Este caso se eligio por su alta distancia, es un punto medio para los cambios de camas y las camas no ideales es un dato bajo
#
# 3) 1, 5, 25, 35
# Este caso se eligio por su alta distancia, la menor cantidad de cambios de camas y el bajo numero de cambios de camas

# %%
graph_by_weights(1, 5, 15, 33)

# %%
graph_by_weights(1, 5, 20, 35)

# %%
graph_by_weights(1, 5, 25, 35)

# %%
A = [0, 0, 0, 0, 8, 8, 8, 8, 8, 8, 8, 8]
general_metrics, metrics_by_block = optimize_beds(130, 100, [1, 5, 20, 35], A)
print(general_metrics)
graph_by_metrics(metrics_by_block)
# Out:
# {'total_distance': 9935, 'beds_changed': 15, 'not_ideal': 108, 'status': 2, 'objective_1': 9935.0, 'objective_2': 102.0, 'objective_3': 108.0, 'objective_4': 15.0}

# %% [markdown]
# ## Analisis de mas de un cambio por paciente

# %%
general_metrics, metrics_by_block = optimize_beds(130, 100, [1, 5, 20, 35], cambios=2)
print(general_metrics)
graph_by_metrics(metrics_by_block)
# Out:
# {'total_distance': 9935, 'beds_changed': 17, 'not_ideal': 108, 'status': 2, 'objective_1': 9935.0, 'objective_2': 116.99999625630522, 'objective_3': 108.0, 'objective_4': 16.999999251261045}

# %%
general_metrics, metrics_by_block = optimize_beds(130, 100, [1, 5, 20, 35], cambios=3)
print(general_metrics)
graph_by_metrics(metrics_by_block)
# Out:
# {'total_distance': 9935, 'beds_changed': 14, 'not_ideal': 108, 'status': 2, 'objective_1': 9935.0, 'objective_2': 96.0, 'objective_3': 108.0, 'objective_4': 14.0}

# %%
general_metrics, metrics_by_block = optimize_beds(130, 100, [1, 5, 20, 35], cambios=8)
print(general_metrics)
graph_by_metrics(metrics_by_block)
# Out:
# {'total_distance': 9935, 'beds_changed': 20, 'not_ideal': 108, 'status': 2, 'objective_1': 9935.0, 'objective_2': 137.9999980392788, 'objective_3': 108.0, 'objective_4': 19.99999971989697}

# %% [markdown]
# ### Analisis de cambios de limite de severidad

# %%
general_metrics, metrics_by_block = optimize_beds(130, 100, [1, 5, 20, 35], Q=6)
print(general_metrics)
graph_by_metrics(metrics_by_block)
# Out:
# {'total_distance': 9935, 'beds_changed': 2, 'not_ideal': 108, 'status': 2, 'objective_1': 9935.0, 'objective_2': 11.0, 'objective_3': 108.0, 'objective_4': 2.0}

# %%
general_metrics, metrics_by_block = optimize_beds(130, 100, [1, 5, 20, 35], Q=8)
print(general_metrics)
graph_by_metrics(metrics_by_block)
# Out:
# {'total_distance': 9935, 'beds_changed': 13, 'not_ideal': 108, 'status': 2, 'objective_1': 9935.0, 'objective_2': 89.0, 'objective_3': 108.0, 'objective_4': 13.0}

# %%
tabla = pd.read_csv(f"analysis_4_blocks/metrics_by_block_{1}_{5}_{20}_{35}.csv")
tabla
# Out:
#     Unnamed: 0  time  changes_per_block  not_ideals_per_block  \
# 0            0     0                  0                     9
# 1            1     2                  0                     9
# 2            2     4                  0                    10
# 3            3     6                  0                    10
# 4            4     8                  1                    10
# 5            5    10                  0                     8
# 6            6    12                  1                     9
# 7            7    14                  3                     9
# 8            8    16                  3                     9
# 9            9    18                  3                     9
# 10          10    20                  0                     9
# 11          11    22                  1                     7
#
#     patients_per_block  dist_per_block
# 0                   89             855
# 1                   89             855
# ...

# %%
metrics_by_block
# Out:
#     time  changes_per_block  not_ideals_per_block  patients_per_block  \
# 0      0                  0                     9                  89
# 1      2                  0                     9                  89
# 2      4                  0                    10                  90
# 3      6                  0                    10                  92
# 4      8                  0                    10                  92
# 5     10                  2                     8                  88
# 6     12                  3                     9                  82
# 7     14                  2                     9                  85
# 8     16                  3                     9                  84
# 9     18                  3                     9                  86
# 10    20                  0                     9                  82
# 11    22                  0                     7                  82
#
#     dist_per_block
# 0              855
# ...
